# %% [markdown]
# # Hackathon KitDatascience 30/11/2018

# %% [markdown]
# <b>Groupe</b> : semi croustillants <br>
# <b>Membres</b> :
# <ul>
#     <li>Abdelfattah Abouelaoualim</li>
#     <li>Arnaud Lejeune</li>
#     <li>Valentin Larrieu</li>
#     <li>Thomas Meimoun</li>
#     <li>Thibault Royet</li>
# </ul>

# %% [markdown]
# # Imports

# %%
# %matplotlib inline 
# notebook

# text formatting
import re
# slugify?

import pandas as pd
import numpy as np
import math
import random
from statistics import mean
import json
import time
import unittest


from bs4 import BeautifulSoup
import requests


# sklearn
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# Vizualisation
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

from pandas import HDFStore,DataFrame

# %% [markdown]
# # Global Variables

# %%
SEED=1234
website_prefix = "https://www.uuu.com"
file_path = "path\\file.csv" # used in get_import_dataframe

# %% [markdown]
# # Global fuctions

# %%
# if there is usefull function, put it there

# %% [markdown]
# # Data Harvesting

# %%
   ########## GET DATA FROM SOURCES
    
    # Scrapp
    
    # Api
    
    # Import
    
    #########

# %%
# Scrap the website *** to give a usefull dataframe

def get_scrap_dataframe():

    # TBD
    """
    # CODE EXAMPLE
    
    url = website_prefix + "" #
    soup = _handle_request_result_and_build_soup(url)

    specific_class = "search-table-data"
    tableContent =soup.find(class_=specific_class).find_all("tr")
    mylinks =[]
    for ind in range (1,len(tableContent)):
        mylinks.append(_clear_url(tableContent[ind].attrs['onclick']))
    """

    df = pd.DataFrame()

    return df

# %%
# Use the *** api to get usefull dataframe

def get_api_dataframe():

    # TBD
    """
    # CODE EXAMPLE
    
    # We read the token which is stored in a local file
    token = open("PATH\\gitToken.txt", encoding="utf8").readline()[:-1]
    
    request = requests.get("https://api.github.com/users/" + username + "/repos", auth=(username_account, token))
    #print("request code ", request.status_code)
    
    json_res = json.loads(request.text)
    #print("jsonres", json_res)
    
    try:
        star_list = [json1["stargazers_count"] for json1 in json_res]
        dict[username] = mean(star_list)
    except:
        dict[username] = 0
    """

    df = pd.DataFrame()

    return df

# %%
# Import data from a csv file

def get_import_dataframe():
    
    na_values = ['?', '']
    file_path = "C:\\Users\\Orion\\Documents\\MS-BGD\\Git\\Valentin_Larrieu\\Hackathon-KitDataScience-30-11-18\\Files\\music.csv"
    df = pd.read_csv(file_path, sep=',', na_values=na_values) # add chunksize=1000 to limit the size then df = next(df)

    # use the global variable file_path to define the path
    #df = pd.DataFrame()

    return df

df_test = get_import_dataframe().sort_values(by='artist.hotttnesss', ascending=False, na_position='last')
df_test
# Out:
#       artist.hotttnesss           artist.id  \
# 8464           1.082503  ARRH63Y1187FB47783
# 4989           1.082503  ARRH63Y1187FB47783
# 2376           1.082503  ARRH63Y1187FB47783
# 7331           1.082503  ARRH63Y1187FB47783
# 7275           1.082503  ARRH63Y1187FB47783
# 6779           1.082503  ARRH63Y1187FB47783
# 1054           1.082503  ARRH63Y1187FB47783
# 9937           1.082503  ARRH63Y1187FB47783
# 2671           1.082503  ARRH63Y1187FB47783
# 4950           1.021256  ARF8HTQ1187B9AE693
# 8123           1.005942  ARTDQRC1187FB4EFD4
# 1568           1.005942  ARTDQRC1187FB4EFD4
# 74             1.005942  ARTDQRC1187FB4EFD4
# 2904           1.005942  ARTDQRC1187FB4EFD4
# 840                       0.992                      Nun singet und seid froh
# 2487                      0.000                                          Dime
# 6422                      0.653                              Sleepy F%#&in' D
# 8871                      0.536                                    Tu Ex Amor
# 2503                      0.658                             Den Mporo Na Figo
# 4363                      0.868                                 GroAraumbrand
# 6382                      0.000                                     Impromptu
# 6327                      0.000                              Someday You Will
# 4983                      0.630                                       Lagrima
# 4358                      0.533      Sonata I.X.1905: I. Preduycha (JanA!cek)
# 6372                      0.775                                     Tempestad
# 793                       0.201                         He Put The Hurt On Me
# 6352                      0.937                     Show Me - Splitloop Remix
# 8927                      0.992                                   Mood Indigo
# 6346                      0.000                           KAPnig und KAPnigin
# 3930                      0.772                               Nomades Monades
# 2543                      1.000                                   Eddie's Pad
# 8951                      0.297                     It's The Three Of Us Left
# 6480                      1.000                                     Kandiyohi
#
#       year
# 8464  2005
# 4989  2010
# 2376  2005
# 7331  2003
# 7275  2005
# 6779  2005
# 1054  2003
# 9937  2005
# 2671  2008
# 4950  1995
# 8123  2000
# 1568  2000
# 74    2004
# 2904  2000
# 2171  2004
# 3886  2008
# 1972  2002
# 9100  2005
# 4202  2003
# 3829  1999
# 5497  2005
# 8281  2005
# 4219     0
# 1235  2007
# 5522  2006
# 955   2007
# 2664  2005
# 4119  2006
# 8522  2007
# 7195  2007
# ...    ...
# 688      0
# 6189     0
# 6182     0
# 8983     0
# 6326     0
# 6441  2003
# 4982     0
# 8841     0
# 2478     0
# 3917     0
# 8851     0
# 840      0
# 2487     0
# 6422     0
# 8871     0
# 2503     0
# 4363     0
# 6382     0
# 6327     0
# 4983     0
# 4358     0
# 6372     0
# 793   2006
# 6352     0
# 8927     0
# 6346     0
# 3930  1997
# 2543     0
# 8951     0
# 6480     0
#
# [10000 rows x 35 columns]

# %%
for column in df_test.columns:
   print("bonjour1", column)
# Out:
# bonjour1 artist.hotttnesss
# bonjour1 artist.id
# bonjour1 artist.name
# bonjour1 artist_mbtags
# bonjour1 artist_mbtags_count
# bonjour1 bars_confidence
# bonjour1 bars_start
# bonjour1 beats_confidence
# bonjour1 beats_start
# bonjour1 duration
# bonjour1 end_of_fade_in
# bonjour1 familiarity
# bonjour1 key
# bonjour1 key_confidence
# bonjour1 latitude
# bonjour1 location
# bonjour1 longitude
# bonjour1 loudness
# bonjour1 mode
# bonjour1 mode_confidence
# bonjour1 release.id
# bonjour1 release.name
# bonjour1 similar
# bonjour1 song.hotttnesss
# bonjour1 song.id
# bonjour1 start_of_fade_out
# bonjour1 tatums_confidence
# bonjour1 tatums_start
# bonjour1 tempo
# bonjour1 terms
# bonjour1 terms_freq
# bonjour1 time_signature
# bonjour1 time_signature_confidence
# bonjour1 title
# bonjour1 year

# %%
plt.figure(88)
plot_pop_depassement = df_test.plot(x='familiarity', y='song.hotttnesss', linewidth = 0, marker='x', color='red', title = "POPULATION as a function of POURCENTAGE_DEPASSEMENT")
plt.show()

plt.figure(88)
plot_pop_depassement = df_test.plot(x='familiarity', y='artist.hotttnesss', linewidth = 0, marker='x', color='red', title = "POPULATION as a function of POURCENTAGE_DEPASSEMENT")
plt.show()

plt.figure(88)
plot_pop_depassement = df_test.plot(x='longitude', y='song.hotttnesss', linewidth = 0, marker='x', color='red', title = "POPULATION as a function of POURCENTAGE_DEPASSEMENT")
plt.show()

# %%
df_test.co

# %% [markdown]
#  # Data joining

# %%
# Join the data of the 3 dataframe

def get_joined_dataframe(df_scrap, df_api, df_import):
    
    # TBD
    
    """
    # CODE EXAMPLE
    
    joined_df_with_pop = pd.merge(joined_df, population_filtered, on='DEPARTEMENTID', left_index=True, right_index=False)
    
    
    """
    
    df = pd.DataFrame()

    return df

# %% [markdown]
# # Data Cleaning

# %%
# Clean the dataframe

def get_cleaned_dataframe(df_in):
    
    # TBD
    
    df = pd.DataFrame()

    return df

# %% [markdown]
# # Data Vizualisation

# %%
# Plot an interesting thing

def vizualise_interesting_thing_1(df_in):
    
    """
    
    # CODE EXAMPLE
    
    plot_pop_depassement = df_in.plot(x='POPULATION', y='POURCENTAGE_DEPASSEMENT', marker='o', color='red', title = "POPULATION as a function of POURCENTAGE_DEPASSEMENT")
    plt.show()
    
    """
    
    return None

# %%
# Plot the results of the model

def plot_my_model(model):
    
    return None

# %% [markdown]
# # Data Explotation

# %%
# Build a model on the data

def build_a_model(df_in):
    
    """
    
    # CODE EXAMPLE
    
    X = spe["EFFECTIFS/POPULATION"]
    Y = spe["POURCENTAGE_DEPASSEMENT"]

    X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=SEED)
    skl_lm = linear_model.LinearRegression(fit_intercept=True)
    skl_lm.fit(X_train, Y_train)
    score = skl_lm.score(X_test, Y_test)
    print("Score: \n", score)
    
    
    """
    
    return None

# %% [markdown]
# # Tests

# %% [markdown]
# ## Test definition & main

# %%
class HackathonTests(unittest.TestCase):

    def test_dummy(self):
        self.assertEqual('foo'.upper(), 'FOO')
        
    def test_return_type(self):
        self.assertEqual(type(get_scrap_dataframe()), type(pd.DataFrame()))    
        self.assertEqual(type(get_api_dataframe()), type(pd.DataFrame()))
        self.assertEqual(type(get_import_dataframe()), type(pd.DataFrame()))
        self.assertEqual(type(get_joined_dataframe(pd.DataFrame(),pd.DataFrame(),pd.DataFrame())), type(pd.DataFrame()))
        self.assertEqual(type(get_cleaned_dataframe(pd.DataFrame())), type(pd.DataFrame()))
        self.assertEqual(type(vizualise_interesting_thing_1(pd.DataFrame())), type(None))
        self.assertEqual(type(build_a_model(pd.DataFrame())), type(None))
        self.assertEqual(type(plot_my_model(pd.DataFrame())), type(None))
        

if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)

def main():
    print("Start \n")


    ########## GET DATA FROM SOURCES
    
    # Scrapp
    df_scrap = get_scrap_dataframe()
    
    # Api
    df_api = get_api_dataframe()
    
    # Import
    df_import = get_import_dataframe()
    
    #########
    
    
    
    ########## DATA JOINING
    
    df_joined = get_joined_dataframe(df_scrap, df_api, df_import)
    
    
    ########
    
    
    ########## DATA CLEANING (after or before join depending on data)
    
    df_cleaned = get_cleaned_dataframe(df_joined)
    
    #########
    
    
    ########## DATA VISUALISATION
    
    vizualise_interesting_thing_1(df_cleaned)
    
    #########
    
    ########## DATA EXPLOTATION
    
    # Use model to predict
    
    model_built = build_a_model(df_cleaned)
    
    plot_my_model(model_built)
    
    
    #########
    

    print("End \n")


main()
# Out:
# ..
# Start
#
# End
# ----------------------------------------------------------------------
# Ran 2 tests in 0.009s
#
# OK
